# %% [markdown]
# The following additional libraries are needed to run this
# notebook. Note that running on Colab is experimental, please report a Github
# issue if you have any problem.

# %%
# %pip install -e ..  # installing local d2l with current dependencies
# Out:
# Obtaining file:///Users/alexjiang/Desktop/Project/d2l-zh-pytorch-colab
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: jupyter in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (1.1.1)
# Requirement already satisfied: numpy in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (2.2.0)
# Requirement already satisfied: matplotlib in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (3.10.0)
# Requirement already satisfied: matplotlib-inline in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (0.2.1)
# Requirement already satisfied: requests in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (2.32.3)
# Requirement already satisfied: pandas in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (2.2.3)
# Requirement already satisfied: pillow in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (11.0.0)
# Requirement already satisfied: torch in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (2.12.0)
# Requirement already satisfied: torchvision in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from d2l==1.0.3.post1) (0.27.0)
# Requirement already satisfied: notebook in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter->d2l==1.0.3.post1) (7.5.6)
# Requirement already satisfied: jupyter-console in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter->d2l==1.0.3.post1) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter->d2l==1.0.3.post1) (7.17.1)
# Requirement already satisfied: ipykernel in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter->d2l==1.0.3.post1) (7.2.0)
# Requirement already satisfied: ipywidgets in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter->d2l==1.0.3.post1) (8.1.8)
# Requirement already satisfied: jupyterlab in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter->d2l==1.0.3.post1) (4.5.7)
# Requirement already satisfied: appnope>=0.1.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (9.12.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (26.0)
# Requirement already satisfied: psutil>=5.7 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipykernel->jupyter->d2l==1.0.3.post1) (5.14.3)
# Requirement already satisfied: decorator>=5.1.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-client>=8.8.0->ipykernel->jupyter->d2l==1.0.3.post1) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter->d2l==1.0.3.post1) (4.9.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel->jupyter->d2l==1.0.3.post1) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.3.post1) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipywidgets->jupyter->d2l==1.0.3.post1) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from ipywidgets->jupyter->d2l==1.0.3.post1) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab->jupyter->d2l==1.0.3.post1) (75.1.0)
# Requirement already satisfied: anyio in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.3.post1) (4.13.0)
# Requirement already satisfied: certifi in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.0.9)
# Requirement already satisfied: idna in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.3.post1) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (4.26.0)
# Requirement already satisfied: typing_extensions>=4.5 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.3.post1) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->d2l==1.0.3.post1) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (0.1.1)
# Requirement already satisfied: fqdn in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.5.1)
# Requirement already satisfied: isoduration in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.1.0)
# Requirement already satisfied: uri-template in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbconvert->jupyter->d2l==1.0.3.post1) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->d2l==1.0.3.post1) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbconvert->jupyter->d2l==1.0.3.post1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbconvert->jupyter->d2l==1.0.3.post1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbconvert->jupyter->d2l==1.0.3.post1) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbconvert->jupyter->d2l==1.0.3.post1) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbconvert->jupyter->d2l==1.0.3.post1) (1.5.1)
# Requirement already satisfied: webencodings in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->d2l==1.0.3.post1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->d2l==1.0.3.post1) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2.21.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from requests->d2l==1.0.3.post1) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from requests->d2l==1.0.3.post1) (2.2.3)
# Requirement already satisfied: lark>=1.2.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2.0.0)
# Requirement already satisfied: pycparser in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->d2l==1.0.3.post1) (2.6)
# Requirement already satisfied: arrow>=0.15.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (1.4.0)
# Requirement already satisfied: tzdata in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.3.post1) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from matplotlib->d2l==1.0.3.post1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from matplotlib->d2l==1.0.3.post1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from matplotlib->d2l==1.0.3.post1) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from matplotlib->d2l==1.0.3.post1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from matplotlib->d2l==1.0.3.post1) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from pandas->d2l==1.0.3.post1) (2024.2)
# Requirement already satisfied: filelock in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from torch->d2l==1.0.3.post1) (3.16.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from torch->d2l==1.0.3.post1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from torch->d2l==1.0.3.post1) (3.4.2)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from torch->d2l==1.0.3.post1) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/alexjiang/opt/anaconda3/envs/hw4/lib/python3.12/site-packages (from sympy>=1.13.3->torch->d2l==1.0.3.post1) (1.3.0)
# Building wheels for collected packages: d2l
#   Building editable for d2l (pyproject.toml) ... done
#   Created wheel for d2l: filename=d2l-1.0.3.post1-0.editable-py3-none-any.whl size=3073 sha256=54afd65269f2e0a983592250c2882689d79263e5032c5b512f2c77527870e95f
#   Stored in directory: /private/var/folders/h7/ymb079h53jg5n5rv8_gq9vtw0000gn/T/pip-ephem-wheel-cache-9twz2l7w/wheels/56/b8/95/7779d4782ea6a940dfca754ba0de97c72319f784ff73ec8a04
# Successfully built d2l
# Installing collected packages: d2l
#   Attempting uninstall: d2l
#     Found existing installation: d2l 1.0.3.post1
#     Uninstalling d2l-1.0.3.post1:
#       Successfully uninstalled d2l-1.0.3.post1
# Successfully installed d2l-1.0.3.post1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 线性回归的从零开始实现
# :label:`sec_linear_scratch`
#
# 在了解线性回归的关键思想之后，我们可以开始通过代码来动手实现线性回归了。
# 在这一节中，(**我们将从零开始实现整个方法，
# 包括数据流水线、模型、损失函数和小批量随机梯度下降优化器**)。
# 虽然现代的深度学习框架几乎可以自动化地进行所有这些工作，但从零开始实现可以确保我们真正知道自己在做什么。
# 同时，了解更细致的工作原理将方便我们自定义模型、自定义层或自定义损失函数。
# 在这一节中，我们将只使用张量和自动求导。
# 在之后的章节中，我们会充分利用深度学习框架的优势，介绍更简洁的实现方式。

# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# ## 生成数据集
#
# 为了简单起见，我们将[**根据带有噪声的线性模型构造一个人造数据集。**]
# 我们的任务是使用这个有限样本的数据集来恢复这个模型的参数。
# 我们将使用低维数据，这样可以很容易地将其可视化。
# 在下面的代码中，我们生成一个包含1000个样本的数据集，
# 每个样本包含从标准正态分布中采样的2个特征。
# 我们的合成数据集是一个矩阵$\mathbf{X}\in \mathbb{R}^{1000 \times 2}$。
#
# (**我们使用线性模型参数$\mathbf{w} = [2, -3.4]^\top$、$b = 4.2$
# 和噪声项$\epsilon$生成数据集及其标签：
#
# $$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon.$$
# **)
#
# $\epsilon$可以视为模型预测和标签时的潜在观测误差。
# 在这里我们认为标准假设成立，即$\epsilon$服从均值为0的正态分布。
# 为了简化问题，我们将标准差设为0.01。
# 下面的代码生成合成数据集。

# %%
def synthetic_data(w, b, num_examples):  #@save
    """生成y=Xw+b+噪声"""
    X = torch.normal(0, 1, (num_examples, len(w)))
    y = torch.matmul(X, w) + b
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1, 1))

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %% [markdown]
# 注意，[**`features`中的每一行都包含一个二维数据样本，
# `labels`中的每一行都包含一维标签值（一个标量）**]。

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: tensor([-1.6832,  1.2817])
# label: tensor([-3.5177])

# %% [markdown]
# 通过生成第二个特征`features[:, 1]`和`labels`的散点图，
# 可以直观观察到两者之间的线性关系。

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %% [markdown]
# ## 读取数据集
#
# 回想一下，训练模型时要对数据集进行遍历，每次抽取一小批量样本，并使用它们来更新我们的模型。
# 由于这个过程是训练机器学习算法的基础，所以有必要定义一个函数，
# 该函数能打乱数据集中的样本并以小批量方式获取数据。
#
# 在下面的代码中，我们[**定义一个`data_iter`函数，
# 该函数接收批量大小、特征矩阵和标签向量作为输入，生成大小为`batch_size`的小批量**]。
# 每个小批量包含一组特征和标签。

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

# %% [markdown]
# 通常，我们利用GPU并行运算的优势，处理合理大小的“小批量”。
# 每个样本都可以并行地进行模型计算，且每个样本损失函数的梯度也可以被并行计算。
# GPU可以在处理几百个样本时，所花费的时间不比处理一个样本时多太多。
#
# 我们直观感受一下小批量运算：读取第一个小批量数据样本并打印。
# 每个批量的特征维度显示批量大小和输入特征数。
# 同样的，批量的标签形状与`batch_size`相等。

# %%
batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    break
# Out:
# tensor([[-1.5878,  0.2394],
#         [-0.7344,  1.1243],
#         [ 0.6026,  1.2102],
#         [ 0.0279, -0.8176],
#         [-0.5876, -0.9489],
#         [ 0.4300,  0.1869],
#         [-1.0804, -0.7290],
#         [ 1.5385, -1.3333],
#         [ 0.2190,  0.6339],
#         [-0.0828, -0.2632]])
#  tensor([[ 0.1967],
#         [-1.0929],
#         [ 1.2991],
#         [ 7.0399],
#         [ 6.2633],
#         [ 4.4259],
#         [ 4.5232],
#         [11.8091],
#         [ 2.4741],
#         [ 4.9431]])

# %% [markdown]
# 当我们运行迭代时，我们会连续地获得不同的小批量，直至遍历完整个数据集。
# 上面实现的迭代对教学来说很好，但它的执行效率很低，可能会在实际问题上陷入麻烦。
# 例如，它要求我们将所有数据加载到内存中，并执行大量的随机内存访问。
# 在深度学习框架中实现的内置迭代器效率要高得多，
# 它可以处理存储在文件中的数据和数据流提供的数据。
#
# ## 初始化模型参数
#
# [**在我们开始用小批量随机梯度下降优化我们的模型参数之前**]，
# (**我们需要先有一些参数**)。
# 在下面的代码中，我们通过从均值为0、标准差为0.01的正态分布中采样随机数来初始化权重，
# 并将偏置初始化为0。

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %% [markdown]
# 在初始化参数之后，我们的任务是更新这些参数，直到这些参数足够拟合我们的数据。
# 每次更新都需要计算损失函数关于模型参数的梯度。
# 有了这个梯度，我们就可以向减小损失的方向更新每个参数。
# 因为手动计算梯度很枯燥而且容易出错，所以没有人会手动计算梯度。
# 我们使用 :numref:`sec_autograd`中引入的自动微分来计算梯度。
#
# ## 定义模型
#
# 接下来，我们必须[**定义模型，将模型的输入和参数同模型的输出关联起来。**]
# 回想一下，要计算线性模型的输出，
# 我们只需计算输入特征$\mathbf{X}$和模型权重$\mathbf{w}$的矩阵-向量乘法后加上偏置$b$。
# 注意，上面的$\mathbf{Xw}$是一个向量，而$b$是一个标量。
# 回想一下 :numref:`subsec_broadcasting`中描述的广播机制：
# 当我们用一个向量加一个标量时，标量会被加到向量的每个分量上。

# %%
def linreg(X, w, b):  #@save
    """线性回归模型"""
    return torch.matmul(X, w) + b

# %% [markdown]
# ## [**定义损失函数**]
#
# 因为需要计算损失函数的梯度，所以我们应该先定义损失函数。
# 这里我们使用 :numref:`sec_linear_regression`中描述的平方损失函数。
# 在实现中，我们需要将真实值`y`的形状转换为和预测值`y_hat`的形状相同。

# %%
def squared_loss(y_hat, y):  #@save
    """均方损失"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %% [markdown]
# ## (**定义优化算法**)
#
# 正如我们在 :numref:`sec_linear_regression`中讨论的，线性回归有解析解。
# 尽管线性回归有解析解，但本书中的其他模型却没有。
# 这里我们介绍小批量随机梯度下降。
#
# 在每一步中，使用从数据集中随机抽取的一个小批量，然后根据参数计算损失的梯度。
# 接下来，朝着减少损失的方向更新我们的参数。
# 下面的函数实现小批量随机梯度下降更新。
# 该函数接受模型参数集合、学习速率和批量大小作为输入。每
# 一步更新的大小由学习速率`lr`决定。
# 因为我们计算的损失是一个批量样本的总和，所以我们用批量大小（`batch_size`）
# 来规范化步长，这样步长大小就不会取决于我们对批量大小的选择。

# %%
def sgd(params, lr, batch_size):  #@save
    """小批量随机梯度下降"""
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad / batch_size
            param.grad.zero_()

# %% [markdown]
# ## 训练
#
# 现在我们已经准备好了模型训练所有需要的要素，可以实现主要的[**训练过程**]部分了。
# 理解这段代码至关重要，因为从事深度学习后，
# 相同的训练过程几乎一遍又一遍地出现。
# 在每次迭代中，我们读取一小批量训练样本，并通过我们的模型来获得一组预测。
# 计算完损失后，我们开始反向传播，存储每个参数的梯度。
# 最后，我们调用优化算法`sgd`来更新模型参数。
#
# 概括一下，我们将执行以下循环：
#
# * 初始化参数
# * 重复以下训练，直到完成
#     * 计算梯度$\mathbf{g} \leftarrow \partial_{(\mathbf{w},b)} \frac{1}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} l(\mathbf{x}^{(i)}, y^{(i)}, \mathbf{w}, b)$
#     * 更新参数$(\mathbf{w}, b) \leftarrow (\mathbf{w}, b) - \eta \mathbf{g}$
#
# 在每个*迭代周期*（epoch）中，我们使用`data_iter`函数遍历整个数据集，
# 并将训练数据集中所有样本都使用一次（假设样本数能够被批量大小整除）。
# 这里的迭代周期个数`num_epochs`和学习率`lr`都是超参数，分别设为3和0.03。
# 设置超参数很棘手，需要通过反复试验进行调整。
# 我们现在忽略这些细节，以后会在 :numref:`chap_optimization`中详细介绍。

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

# %%
for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        l = loss(net(X, w, b), y)  # X和y的小批量损失
        # 因为l形状是(batch_size,1)，而不是一个标量。l中的所有元素被加到一起，
        # 并以此计算关于[w,b]的梯度
        l.sum().backward()
        sgd([w, b], lr, batch_size)  # 使用参数的梯度更新参数
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 0.052817
# epoch 2, loss 0.000232
# epoch 3, loss 0.000049

# %% [markdown]
# 因为我们使用的是自己合成的数据集，所以我们知道真正的参数是什么。
# 因此，我们可以通过[**比较真实参数和通过训练学到的参数来评估训练的成功程度**]。
# 事实上，真实参数和通过训练学到的参数确实非常接近。

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 0.0006, -0.0009], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0011], grad_fn=<RsubBackward1>)

# %% [markdown]
# 注意，我们不应该想当然地认为我们能够完美地求解参数。
# 在机器学习中，我们通常不太关心恢复真正的参数，而更关心如何高度准确预测参数。
# 幸运的是，即使是在复杂的优化问题上，随机梯度下降通常也能找到非常好的解。
# 其中一个原因是，在深度网络中存在许多参数组合能够实现高度精确的预测。
#
# ## 小结
#
# * 我们学习了深度网络是如何实现和优化的。在这一过程中只使用张量和自动微分，不需要定义层或复杂的优化器。
# * 这一节只触及到了表面知识。在下面的部分中，我们将基于刚刚介绍的概念描述其他模型，并学习如何更简洁地实现其他模型。
#
# ## 练习
#
# 1. 如果我们将权重初始化为零，会发生什么。算法仍然有效吗？
# 1. 假设试图为电压和电流的关系建立一个模型。自动微分可以用来学习模型的参数吗?
# 1. 能基于[普朗克定律](https://en.wikipedia.org/wiki/Planck%27s_law)使用光谱能量密度来确定物体的温度吗？
# 1. 计算二阶导数时可能会遇到什么问题？这些问题可以如何解决？
# 1. 为什么在`squared_loss`函数中需要使用`reshape`函数？
# 1. 尝试使用不同的学习率，观察损失函数值下降的快慢。
# 1. 如果样本个数不能被批量大小整除，`data_iter`函数的行为会有什么变化？

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/1778)
